# %%
import tensorflow_data_validation as tfdv
import tensorflow as tf

# Path to the data directory
DATA_DIR = './datasets/salaries/ds_salaries.csv'

# Path to the label column
LABEL_COLUMN = 'company_size'

stats = tfdv.generate_statistics_from_csv(DATA_DIR)

tfdv.visualize_statistics(stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
schema = tfdv.infer_schema(statistics=stats)
tfdv.display_schema(schema=schema)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_31462/3951150424.py in <cell line: 1>()
# ----> 1 tfdv.display_schema(stats)
#
# ~/.local/lib/python3.10/site-packages/tensorflow_data_validation/utils/display_util.py in display_schema(schema)
#     214     schema: A Schema protocol buffer.
#     215   """
# --> 216   features_df, domains_df = get_schema_dataframe(schema)
#     217   display(features_df)
#     218   # Do not truncate columns.
#
# ~/.local/lib/python3.10/site-packages/tensorflow_data_validation/utils/display_util.py in get_schema_dataframe(schema)
#      81   """
#      82   if not isinstance(schema, schema_pb2.Schema):
# ---> 83     raise TypeError(
#      84         'schema is of type %s, should be a Schema proto.'
#      85         % type(schema).__name__
#
# TypeError: schema is of type DatasetFeatureStatisticsList, should be a Schema proto.
